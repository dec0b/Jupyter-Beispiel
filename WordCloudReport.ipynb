# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("SearchTermReportTAB.txt", delimiter="\t")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16764 entries, 0 to 16763
# Data columns (total 15 columns):
# SearchTerm        16764 non-null object
# MatchType         16762 non-null object
# Added/Excluded    16762 non-null object
# Campaign          16762 non-null object
# AdGroup           16762 non-null object
# Clicks            16764 non-null int64
# Impr              16764 non-null int64
# CTR               16764 non-null object
# CurrencyCode      16764 non-null object
# AvgCPC            16764 non-null object
# Cost              16764 non-null float64
# Conversions       16764 non-null float64
# Cost/conv         16764 non-null float64
# ConvRate          16764 non-null object
# CampaignType      16762 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 1.9+ MB

# %%
df = df1.drop(df1.index[len(df1)-2:])
df

df_impr = df[['SearchTerm','Impr']]
df_impr

# list = " ".join(word for word in )


# text2 = " ".join(term for term in df.SearchTerm[0:len(df.SearchTerm)-2])
# Out:
#                                               SearchTerm  Impr
# 0                                  hotel online bezahlen     9
# 1                                       hotel locvillare     2
# 2                                      alsterdorf hotels     2
# 3      genuss hotel tirolensiswird in neuem fenster g...     1
# 4                                        hotel reulingen     1
# 5                                          poiprad hotel     1
# 6                                            togau hotel     1
# 7                                    hotel vaihingen enz     3
# 8                                       hotels inssbruck     1
# 9                                     eretz zeelim hotel     2
# 10                                       lauenburg hotel    15
# 11                                 lyall apartment hotel     1
# 12                                       hotel summerhof     2
# 13                                  07.09 09.09 18 hotel     1
# ...

# %%
# list = " ".join(word for word in )
# wordlist = " ".join(word for word in df_impr.SearchTerm[])


wordlist = " ".join(word for word in df_impr.SearchTerm[0:len(df_impr.SearchTerm)]*df_impr.Impr[word])
wordlist


# wordlist = " ".join(word for word in df_impr[])


# text2 = " ".join(term for term in df.SearchTerm[0:len(df.SearchTerm)-2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-852871a319e1> in <module>()
#       3
#       4
# ----> 5 wordlist = " ".join(word for word in df_impr.SearchTerm[0:len(df_impr.SearchTerm)]*df_impr.Impr[word])
#       6 wordlist
#       7
#
# NameError: name 'word' is not defined

# %%
list = []
for x in range(0,10):
    list.append(df.SearchTerm[x]*df.Impr[x])
print(list)

# text element is used to display all search terms as single string.

text2 = " ".join(term for term in df.SearchTerm[0:len(df.SearchTerm)-2])


text3 = " ".join((term for term in df.SearchTerm[0:len(df.SearchTerm)-2])*(count for count in df.Impr[0:len(df.Impr)-2]))
# Out:
# ['hotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlen', 'hotel locvillarehotel locvillare', 'alsterdorf hotelsalsterdorf hotels', 'genuss hotel tirolensiswird in neuem fenster geöffnet genuss hotel tirolensis', 'hotel reulingen', 'poiprad hotel', 'togau hotel', 'hotel vaihingen enzhotel vaihingen enzhotel vaihingen enz', 'hotels inssbruck', 'eretz zeelim hoteleretz zeelim hotel']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-3319ab39f2f9> in <module>()
#       9
#      10
# ---> 11 text3 = " ".join((term for term in df.SearchTerm[0:len(df.SearchTerm)-2])*(count for count in df.Impr[0:len(df.Impr)-2]))
#      12
#      13
#
# TypeError: unsupported operand type(s) for *: 'generator' and 'generator'

# %%
wordcloud1 = WordCloud(background_color="white").generate(list)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()


wordcloud = WordCloud(background_color="white").generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

#wordcloud = WordCloud(background_color="white").generate(list)

#plt.imshow(wordcloud, interpolation='bilinear')

#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-f61d3b8c91da> in <module>()
# ----> 1 wordcloud1 = WordCloud(background_color="white").generate(list)
#       2 plt.imshow(wordcloud, interpolation='bilinear')
#       3 plt.axis("off")
#       4 plt.show()
#       5
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     603         self
#     604         """
# --> 605         return self.generate_from_text(text)
#     606
#     607     def _check_generated(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     584         self
#     585         """
# --> 586         words = self.process_text(text)
#     587         self.generate_from_frequencies(words)
#     588         return self
#
# ...

# %%
print("There are {} observations and {} metrics in this dataset. \n".format(df.shape[0],df.shape[1]))
# Out:
# There are 16762 observations and 15 metrics in this dataset.

# %%
campaign = df.groupby("Campaign")

# %%
campaign.describe().head()
# Out:
#                                Clicks                                        \
#                                 count       mean         std  min  25%  50%
# Campaign
# DE_Generic_Fremdbrands_Exact    216.0  30.847222  270.863271  0.0  1.0  1.0
# DE_Generic_ohne KK              360.0   1.425000    1.396349  1.0  1.0  1.0
# DE_Generic_tCPA higher          125.0  42.176000  274.692058  0.0  1.0  1.0
# DE_Generic_tCPA highest        1199.0   8.284404  127.020755  0.0  1.0  1.0
# DE_Generic_tCPA lower         11071.0   1.338361    7.361504  0.0  1.0  1.0
#
#                                           Conversions              ...     \
#                               75%     max       count      mean    ...
# Campaign                                                           ...
# DE_Generic_Fremdbrands_Exact  2.0  3315.0       216.0  0.578704    ...
# DE_Generic_ohne KK            1.0    16.0       360.0  0.058333    ...
# ...

# %%
plt.figure(figsize=(15,10))
campaign.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Campaign")
plt.ylabel("Number of clicks")
plt.show()

# %%
list = []

for x in range(0,10):
    list.append(df.SearchTerm[x]*df.Impr[x])
print(list)
# Out:
# ['hotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlenhotel online bezahlen', 'hotel locvillarehotel locvillare', 'alsterdorf hotelsalsterdorf hotels', 'genuss hotel tirolensiswird in neuem fenster geöffnet genuss hotel tirolensis', 'hotel reulingen', 'poiprad hotel', 'togau hotel', 'hotel vaihingen enzhotel vaihingen enzhotel vaihingen enz', 'hotels inssbruck', 'eretz zeelim hoteleretz zeelim hotel']

# %%
#df = df1.drop(df1.index[len(df1)-2:])
#df

#df_impr = df[['SearchTerm','Impr']]
#df_impr

# list = " ".join(word for word in )


# text2 = " ".join(term for term in df.SearchTerm[0:len(df.SearchTerm)-2])

#list_tuples = []
#for x in range(0,len(df_impr.SearchTerm)):
#   list_tuples.append((df_impr.SearchTerm[x],df_impr.Impr[x]))
#print(list_tuples)


list_tuples = tuple(zip(df_impr.SearchTerm,df_impr.Impr))
list_tuples
# Out:
# (('hotel online bezahlen', 9),
#  ('hotel locvillare', 2),
#  ('alsterdorf hotels', 2),
#  ('genuss hotel tirolensiswird in neuem fenster geöffnet genuss hotel tirolensis',
#   1),
#  ('hotel reulingen', 1),
#  ('poiprad hotel', 1),
#  ('togau hotel', 1),
#  ('hotel vaihingen enz', 3),
#  ('hotels inssbruck', 1),
#  ('eretz zeelim hotel', 2),
#  ('lauenburg hotel', 15),
#  ('lyall apartment hotel', 1),
#  ('hotel summerhof', 2),
#  ('07.09 09.09 18 hotel', 1),
#  ('hotelfinder', 185),
#  ('turkish airlines hotel buchen', 1),
#  ('hotels in der nähe hausbroicher straße', 2),
#  ('sengenthal hotel', 4),
#  ('masbate hotels', 1),
#  ('hotel nähe finkenstr 67661', 1),
#  ('hotel region ammersee', 1),
#  ('hotelangebote', 109),
#  ('hotel parkwohnst', 1),
#  ('hotels berlin ohne kreditkarte nähe bue man group', 2),
#  ('hlf hotel buchen', 1),
#  ('günstiges hotel buchen', 19),
#  ('hotels in wusterhausen', 1),
#  ('slef service hotel', 1),
#  ('hotel aquarell cegled', 2),
# ...

# %%
# wordcloud_freq = WordCloud(width=800, height=600, relative_scaling=0.8).generate_from_frequencies(list_tuples)

wordcloud_freq = WordCloud().generate_from_frequencies(list_tuples)

plt.imshow(wordcloud_freq, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-18330458e8e3> in <module>()
#       1 # wordcloud_freq = WordCloud(width=800, height=600, relative_scaling=0.8).generate_from_frequencies(list_tuples)
#       2
# ----> 3 wordcloud_freq = WordCloud().generate_from_frequencies(list_tuples)
#       4
#       5 plt.imshow(wordcloud_freq, interpolation="bilinear")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     378         """
#     379         # make sure frequencies are sorted and normalized
# --> 380         frequencies = sorted(frequencies.items(), key=itemgetter(1), reverse=True)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
#
# ...

# %%
# text element is used to display all search terms as single string.

# text = " ".join(review for review in df.SearchTerm[0:len(df.SearchTerm)-2])

# %%
text
# Out:
# "hotel online bezahlen hotel locvillare alsterdorf hotels genuss hotel tirolensiswird in neuem fenster geöffnet genuss hotel tirolensis hotel reulingen poiprad hotel togau hotel hotel vaihingen enz hotels inssbruck eretz zeelim hotel lauenburg hotel lyall apartment hotel hotel summerhof 07.09 09.09 18 hotel hotelfinder turkish airlines hotel buchen hotels in der nähe hausbroicher straße sengenthal hotel masbate hotels hotel nähe finkenstr 67661 hotel region ammersee hotelangebote hotel parkwohnst hotels berlin ohne kreditkarte nähe bue man group hlf hotel buchen günstiges hotel buchen hotels in wusterhausen slef service hotel hotel aquarell cegled hotel münsater günstige hotels in amsterdam ohne kreditkarte hotel weile weiden wagners hotel vinkovci hotel hotels wiesenburg hotel in der nähe von schalsum hotel obermarktdorf hotels arbaco hotels in vaihingen macanet de cabrenys hotel hotel münschen bertha hotel seddin hotel darmadt ähliches hotel einruhr hotel autobahn motel hotel lona2
# ...

# %%
print("There are {} search words in total across {} searches.".format(len(text.split()),df.shape[0]))
# Out:
# There are 43653 search words in total across 16762 searches.

# %%
stopwords = set(STOPWORDS)
stopwords.update(["hotel","der","von","am"])

# %%
# ?WordCloud

# %%
# wordcloud = WordCloud(stopwords=stopwords,background_color="white").generate_from_frequencies(text)

wordcloud = WordCloud(stopwords=stopwords, width=1000, height=1000, relative_scaling=0.0).generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
topsearch = df.sort_values('Impr',ascending=False).head(18000)
topsearch
# Out:
#                                             SearchTerm  \
# 11165                                      booking com
# 16450                                            hotel
# 16728                                         hotel de
# 10294                                     hotel buchen
# 725                                              hotel
# 10271                                           hotels
# 14337                                       hotelsuche
# 6363                                   www booking com
# 925                                              hotel
# 11458                                            hotel
# 16169                                       bookingcom
# 6564                                            hotels
# 13814                                    check24 hotel
# 15357                                    hotels buchen
# 16172                                            agoda
# 6968                                 hotel in der nähe
# ...

# %%
# ?WordCloud

# %%
print(df.Impr)
# Out:
# 0          9
# 1          2
# 2          2
# 3          1
# 4          1
# 5          1
# 6          1
# 7          3
# 8          1
# 9          2
# 10        15
# 11         1
# 12         2
# 13         1
# 14       185
# 15         1
# 16         2
# 17         4
# 18         1
# 19         1
# 20         1
# 21       109
# 22         1
# 23         2
# 24         1
# 25        19
# 26         1
# 27         1
# 28         2
# 29         1
#         ...
# 16732      1
# 16733      1
# 16734      6
# 16735      2
# 16736     86
# 16737      8
# 16738      1
# 16739      3
# 16740      1
# 16741      7
# 16742      2
# 16743    152
# 16744     35
# 16745      1
# 16746     47
# 16747      2
# 16748     16
# 16749      1
# 16750     31
# 16751      1
# 16752      3
# 16753      6
# 16754      1
# 16755      1
# 16756      1
# 16757      6
# 16758      4
# 16759      1
# 16760      1
# 16761    564
# Name: Impr, Length: 16762, dtype: int64
